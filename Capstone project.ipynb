# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\HP\Downloads\indian-national-level-election.csv\indian-national-level-election.csv")

# %%
df
# Out:
#                          st_name  year  pc_no                    pc_name  \
# 0      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 1      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 2      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 3      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 4      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# ...                          ...   ...    ...                        ...
# 73076                West Bengal  2014     42                    Birbhum
# 73077                West Bengal  2014     42                    Birbhum
# 73078                West Bengal  2014     42                    Birbhum
# 73079                West Bengal  2014     42                    Birbhum
# 73080                West Bengal  2014     42                    Birbhum
#
#       pc_type                 cand_name cand_sex                 partyname  \
# ...

# %%
df.isna().sum()
# Out:
# st_name          0
# year             0
# pc_no            0
# pc_name          0
# pc_type       8070
# cand_name        0
# cand_sex       542
# partyname        0
# partyabbre       0
# totvotpoll       0
# electors         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73081 entries, 0 to 73080
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   st_name     73081 non-null  object
#  1   year        73081 non-null  int64
#  2   pc_no       73081 non-null  int64
#  3   pc_name     73081 non-null  object
#  4   pc_type     65011 non-null  object
#  5   cand_name   73081 non-null  object
#  6   cand_sex    72539 non-null  object
#  7   partyname   73081 non-null  object
#  8   partyabbre  73081 non-null  object
#  9   totvotpoll  73081 non-null  int64
#  10  electors    73081 non-null  int64
# dtypes: int64(4), object(7)
# memory usage: 6.1+ MB

# %%
df.describe()
# Out:
#                year         pc_no     totvotpoll      electors
# count  73081.000000  73081.000000   73081.000000  7.308100e+04
# mean    1996.779505     22.311490   49834.760266  1.122277e+06
# std       10.432527     19.039793  104893.319706  3.560049e+05
# min     1977.000000      1.000000       0.000000  1.947100e+04
# 25%     1989.000000      7.000000     872.000000  9.129850e+05
# 50%     1996.000000     18.000000    2743.000000  1.099503e+06
# 75%     2004.000000     33.000000   19185.000000  1.329086e+06
# max     2014.000000     85.000000  863358.000000  3.368399e+06

# %%
df.dropna(inplace=True)
df
# Out:
#                          st_name  year  pc_no                    pc_name  \
# 0      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 1      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 2      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 3      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 4      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# ...                          ...   ...    ...                        ...
# 73075                West Bengal  2014     42                    Birbhum
# 73077                West Bengal  2014     42                    Birbhum
# 73078                West Bengal  2014     42                    Birbhum
# 73079                West Bengal  2014     42                    Birbhum
# 73080                West Bengal  2014     42                    Birbhum
#
#       pc_type                 cand_name cand_sex                 partyname  \
# ...

# %%
df.isna().sum()
# Out:
# st_name       0
# year          0
# pc_no         0
# pc_name       0
# pc_type       0
# cand_name     0
# cand_sex      0
# partyname     0
# partyabbre    0
# totvotpoll    0
# electors      0
# dtype: int64

# %%
df['st_name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa',
#        'Goa Daman & Diu', 'Goa, Daman & Diu', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Lakshadweep', 'Madhya Pradesh', 'Maharashtra',
#        'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'National Capital Territory Of Delhi', 'Nct Of Delhi', 'Odisha',
#        'Orissa', 'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'Uttaranchal', 'West Bengal'], dtype=object)

# %%
df[df['st_name'] == 'Daman & Diu']
# Out:
#            st_name  year  pc_no        pc_name pc_type  \
# 15127  Daman & Diu  1989      1  Daman And Diu     GEN
# 15128  Daman & Diu  1989      1  Daman And Diu     GEN
# 15129  Daman & Diu  1989      1  Daman And Diu     GEN
# 15130  Daman & Diu  1989      1  Daman And Diu     GEN
# 15131  Daman & Diu  1989      1  Daman And Diu     GEN
# 15132  Daman & Diu  1991      1  Daman And Diu     GEN
# 15133  Daman & Diu  1991      1  Daman And Diu     GEN
# 15134  Daman & Diu  1991      1  Daman And Diu     GEN
# 15135  Daman & Diu  1991      1  Daman And Diu     GEN
# 15136  Daman & Diu  1991      1  Daman And Diu     GEN
# 15137  Daman & Diu  1991      1  Daman And Diu     GEN
# 15138  Daman & Diu  1991      1  Daman And Diu     GEN
# 15139  Daman & Diu  1991      1  Daman And Diu     GEN
# 15140  Daman & Diu  1991      1  Daman And Diu     GEN
# 15141  Daman & Diu  1991      1  Daman And Diu     GEN
# 15142  Daman & Diu  1991      1  Daman And Diu     GEN
# ...

# %%
df[df['st_name'] == 'Goa Daman & Diu'].shape
# Out:
# (36, 11)

# %%
df[df['st_name'] == 'Goa, Daman & Diu'].shape
# Out:
# (13, 11)

# %%
df[df['st_name'] == 'Goa']
# Out:
#       st_name  year  pc_no    pc_name pc_type                      cand_name  \
# 15366     Goa  1989      1     Panaji     GEN           Govind Subrai Naique
# 15367     Goa  1989      1     Panaji     GEN         Naresh Miraji Mirajkar
# 15368     Goa  1989      1     Panaji     GEN              Anthony Leao Dias
# 15369     Goa  1989      1     Panaji     GEN               Hamda Issak Khan
# 15370     Goa  1989      1     Panaji     GEN      Gansham Sadashiv Satoskar
# ...       ...   ...    ...        ...     ...                            ...
# 15532     Goa  2014      2  South Goa     GEN             Govind Shepu Gaude
# 15533     Goa  2014      2  South Goa     GEN                Swati S. Kerkar
# 15534     Goa  2014      2  South Goa     GEN               Churchill Alemao
# 15535     Goa  2014      2  South Goa     GEN      Aleixo Reginaldo Lourenco
# 15536     Goa  2014      2  South Goa     GEN  Adv. Narendra Keshav Sawaikar
#
# ...

# %%
df[df['st_name'] == 'Dadra & Nagar Haveli']
# Out:
#                     st_name  year  pc_no               pc_name pc_type  \
# 15065  Dadra & Nagar Haveli  1977      1  Dadra & Nagar Haveli      ST
# 15066  Dadra & Nagar Haveli  1977      1  Dadra & Nagar Haveli      ST
# 15067  Dadra & Nagar Haveli  1977      1  Dadra & Nagar Haveli      ST
# 15068  Dadra & Nagar Haveli  1980      1  Dadra & Nagar Haveli      ST
# 15069  Dadra & Nagar Haveli  1980      1  Dadra & Nagar Haveli      ST
# 15070  Dadra & Nagar Haveli  1980      1  Dadra & Nagar Haveli      ST
# 15071  Dadra & Nagar Haveli  1980      1  Dadra & Nagar Haveli      ST
# 15072  Dadra & Nagar Haveli  1984      1  Dadra & Nagar Haveli      ST
# 15073  Dadra & Nagar Haveli  1984      1  Dadra & Nagar Haveli      ST
# 15074  Dadra & Nagar Haveli  1984      1  Dadra & Nagar Haveli      ST
# 15075  Dadra & Nagar Haveli  1984      1  Dadra & Nagar Haveli      ST
# 15076  Dadra & Nagar Haveli  1989      1  Dadra & Nagar Haveli      ST
# ...

# %%
df[df.duplicated()]
# Out:
#        st_name  year  pc_no  pc_name pc_type cand_name cand_sex    partyname  \
# 19110  Haryana  1989      8  Bhiwani     GEN    Ishwar        M  Independent
#
#       partyabbre  totvotpoll  electors
# 19110        IND          57    944629

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#                          st_name  year  pc_no                    pc_name  \
# 0      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 1      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 2      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 3      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 4      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# ...                          ...   ...    ...                        ...
# 73075                West Bengal  2014     42                    Birbhum
# 73077                West Bengal  2014     42                    Birbhum
# 73078                West Bengal  2014     42                    Birbhum
# 73079                West Bengal  2014     42                    Birbhum
# 73080                West Bengal  2014     42                    Birbhum
#
#       pc_type                 cand_name cand_sex                 partyname  \
# ...

# %%
index = df[(df['st_name'] == 'Goa, Daman & Diu') | (df['st_name'] == 'Goa Daman & Diu')].index
df.drop(index,inplace=True)

# %%
df['st_name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Delhi', 'Goa', 'Gujarat',
#        'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand',
#        'Karnataka', 'Kerala', 'Lakshadweep', 'Madhya Pradesh',
#        'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram', 'Nagaland',
#        'National Capital Territory Of Delhi', 'Nct Of Delhi', 'Odisha',
#        'Orissa', 'Pondicherry', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Tripura', 'Uttar Pradesh', 'Uttarakhand',
#        'Uttaranchal', 'West Bengal'], dtype=object)

# %%
df[df['st_name'] == 'National Capital Territory Of Delhi']
# Out:
#                                    st_name  year  pc_no     pc_name pc_type  \
# 39882  National Capital Territory Of Delhi  1977      1   New Delhi     GEN
# 39883  National Capital Territory Of Delhi  1977      1   New Delhi     GEN
# 39884  National Capital Territory Of Delhi  1977      1   New Delhi     GEN
# 39885  National Capital Territory Of Delhi  1977      1   New Delhi     GEN
# 39886  National Capital Territory Of Delhi  1977      1   New Delhi     GEN
# ...                                    ...   ...    ...         ...     ...
# 41700  National Capital Territory Of Delhi  2004      7  Karol Bagh      SC
# 41701  National Capital Territory Of Delhi  2004      7  Karol Bagh      SC
# 41702  National Capital Territory Of Delhi  2004      7  Karol Bagh      SC
# 41703  National Capital Territory Of Delhi  2004      7  Karol Bagh      SC
# 41704  National Capital Territory Of Delhi  2004      7  Karol Bagh      SC
#
# ...

# %%
df[df['st_name'] == 'Nct Of Delhi']
# Out:
#             st_name  year  pc_no                         pc_name pc_type  \
# 41865  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41866  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41867  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41868  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41869  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# ...             ...   ...    ...                             ...     ...
# 42017  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42018  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42019  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42020  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42021  Nct Of Delhi  2014      7  South Delhi                        GEN
#
#                    cand_name cand_sex partyname partyabbre  totvotpoll  \
# ...

# %%
df[df['st_name'] == 'Delhi']
# Out:
#       st_name  year  pc_no     pc_name pc_type                   cand_name  \
# 15177   Delhi  1984      1   New Delhi     GEN                    Babu Ram
# 15178   Delhi  1984      1   New Delhi     GEN          Arjun Singh Gulati
# 15179   Delhi  1984      1   New Delhi     GEN                 Ashok Kumar
# 15180   Delhi  1984      1   New Delhi     GEN                  Roshan Lal
# 15181   Delhi  1984      1   New Delhi     GEN                Mahesh Bhola
# ...       ...   ...    ...         ...     ...                         ...
# 15361   Delhi  1984      7  Karol Bagh      SC               Thamai Prasad
# 15362   Delhi  1984      7  Karol Bagh      SC                  B.L.Jagrat
# 15363   Delhi  1984      7  Karol Bagh      SC                   Garib Das
# 15364   Delhi  1984      7  Karol Bagh      SC        Surender Pal Rathwal
# 15365   Delhi  1984      7  Karol Bagh      SC  Sunderwati Nawal Prabhakar
#
# ...

# %%
data_delhi = df['st_name']
data_delhi
# Out:
# 0        Andaman & Nicobar Islands
# 1        Andaman & Nicobar Islands
# 2        Andaman & Nicobar Islands
# 3        Andaman & Nicobar Islands
# 4        Andaman & Nicobar Islands
#                    ...
# 73075                  West Bengal
# 73077                  West Bengal
# 73078                  West Bengal
# 73079                  West Bengal
# 73080                  West Bengal
# Name: st_name, Length: 64419, dtype: object

# %%
df.replace(to_replace=["Delhi","National Capital Territory Of Delhi"],
           value= "Nct Of Delh", inplace=True)

# %%
df
# Out:
#                          st_name  year  pc_no                    pc_name  \
# 0      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 1      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 2      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 3      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 4      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# ...                          ...   ...    ...                        ...
# 73075                West Bengal  2014     42                    Birbhum
# 73077                West Bengal  2014     42                    Birbhum
# 73078                West Bengal  2014     42                    Birbhum
# 73079                West Bengal  2014     42                    Birbhum
# 73080                West Bengal  2014     42                    Birbhum
#
#       pc_type                 cand_name cand_sex                 partyname  \
# ...

# %%
df[df['st_name'] =='Nct Of Delhi']
# Out:
#             st_name  year  pc_no                         pc_name pc_type  \
# 41865  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41866  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41867  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41868  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# 41869  Nct Of Delhi  2014      1  Chandni Chowk                      GEN
# ...             ...   ...    ...                             ...     ...
# 42017  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42018  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42019  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42020  Nct Of Delhi  2014      7  South Delhi                        GEN
# 42021  Nct Of Delhi  2014      7  South Delhi                        GEN
#
#                    cand_name cand_sex partyname partyabbre  totvotpoll  \
# ...

# %%
df['st_name'].unique()
# Out:
# array(['Andaman & Nicobar Islands', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra & Nagar Haveli', 'Daman & Diu', 'Nct Of Delh', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Nct Of Delhi', 'Odisha', 'Orissa', 'Pondicherry',
#        'Puducherry', 'Punjab', 'Rajasthan', 'Sikkim', 'Tamil Nadu',
#        'Tripura', 'Uttar Pradesh', 'Uttarakhand', 'Uttaranchal',
#        'West Bengal'], dtype=object)

# %%
df[df['st_name'] == 'Uttarakhand']
# Out:
#            st_name  year  pc_no        pc_name pc_type  \
# 69300  Uttarakhand  2014      1  Tehri Garhwal     GEN
# 69301  Uttarakhand  2014      1  Tehri Garhwal     GEN
# 69302  Uttarakhand  2014      1  Tehri Garhwal     GEN
# 69303  Uttarakhand  2014      1  Tehri Garhwal     GEN
# 69304  Uttarakhand  2014      1  Tehri Garhwal     GEN
# ...            ...   ...    ...            ...     ...
# 69374  Uttarakhand  2014      5        Hardwar     GEN
# 69375  Uttarakhand  2014      5        Hardwar     GEN
# 69376  Uttarakhand  2014      5        Hardwar     GEN
# 69377  Uttarakhand  2014      5        Hardwar     GEN
# 69378  Uttarakhand  2014      5        Hardwar     GEN
#
#                       cand_name cand_sex partyname partyabbre  totvotpoll  \
# 69300   Jauhari Lal Suman(Muni)        M     BMNSP      BMNSP         877
# 69301           Satendra Sharma        M      NADP       NADP         878
# 69302         Haji Mohd. Yousuf        M      PECP       PECP         900
# ...

# %%
df[df['st_name'] == 'Pondicherry']
# Out:
#            st_name  year  pc_no      pc_name pc_type  \
# 43593  Pondicherry  1977      1  Pondicherry     GEN
# 43594  Pondicherry  1977      1  Pondicherry     GEN
# 43595  Pondicherry  1977      1  Pondicherry     GEN
# 43596  Pondicherry  1977      1  Pondicherry     GEN
# 43597  Pondicherry  1980      1  Pondicherry     GEN
# ...            ...   ...    ...          ...     ...
# 43689  Pondicherry  2004      1  Pondicherry     GEN
# 43690  Pondicherry  2004      1  Pondicherry     GEN
# 43691  Pondicherry  2004      1  Pondicherry     GEN
# 43692  Pondicherry  2004      1  Pondicherry     GEN
# 43693  Pondicherry  2004      1  Pondicherry     GEN
#
#                        cand_name cand_sex  \
# 43593           Gadjindra Baskar        M
# 43594  Ramu Alias Subramanian N.        M
# 43595           Ansari Duraisamy        M
# 43596      Aravinda Bala Pajanor        M
# 43597                 P. Devaraj        M
# ...                          ...      ...
# ...

# %%
df.replace(to_replace=["Uttaranchal"],
           value= "Uttarakhand", inplace=True)

# %%
df[df['st_name'] == 'Puducherry']
# Out:
#           st_name  year  pc_no     pc_name pc_type  \
# 43722  Puducherry  2014      1  Puducherry     GEN
# 43723  Puducherry  2014      1  Puducherry     GEN
# 43724  Puducherry  2014      1  Puducherry     GEN
# 43725  Puducherry  2014      1  Puducherry     GEN
# 43726  Puducherry  2014      1  Puducherry     GEN
# 43727  Puducherry  2014      1  Puducherry     GEN
# 43728  Puducherry  2014      1  Puducherry     GEN
# 43729  Puducherry  2014      1  Puducherry     GEN
# 43730  Puducherry  2014      1  Puducherry     GEN
# 43731  Puducherry  2014      1  Puducherry     GEN
# 43732  Puducherry  2014      1  Puducherry     GEN
# 43733  Puducherry  2014      1  Puducherry     GEN
# 43734  Puducherry  2014      1  Puducherry     GEN
# 43735  Puducherry  2014      1  Puducherry     GEN
# 43736  Puducherry  2014      1  Puducherry     GEN
# 43737  Puducherry  2014      1  Puducherry     GEN
# 43738  Puducherry  2014      1  Puducherry     GEN
# ...

# %%
df.replace(to_replace=["Puducherry"],
           value= "Pondicherry", inplace=True)

# %%
df[df['cand_sex'] == 'O']
# Out:
#              st_name  year  pc_no      pc_name pc_type             cand_name  \
# 25750      Karnataka  2014     18  Chitradurga      SC             T.Bhavana
# 38766    Maharashtra  2014     10      Nagpur      GEN  Senapati Uttam Sapan
# 54082     Tamil Nadu  2014     32      Madurai     GEN     Bharathi Kannamma
# 68448  Uttar Pradesh  2014     37       Amethi     GEN          Sonam Kinnar
# 68940  Uttar Pradesh  2014     66       Deoria     GEN         Barkha Kinnar
# 69161  Uttar Pradesh  2014     77     Varanasi     GEN         Baseer Kinnar
#
#       cand_sex partyname partyabbre  totvotpoll  electors
# 25750        O       IND        IND        3601   1661277
# 38766        O       IND        IND        2017   1900784
# 54082        O       IND        IND        1226   1441434
# 68448        O       IND        IND        1252   1669843
# 68940        O       IND        IND        4124   1806926
# 69161        O       IND        IND        2850   1766487

# %%
df.replace(to_replace=['O'], value ='F', inplace=True)

# %%
df['cand_sex'].value_counts()
# Out:
# M    61324
# F     3095
# Name: cand_sex, dtype: int64

# %%
data = df['partyname'].value_counts(ascending=False)
data
# Out:
# Independent                 27617
# IND                          5619
# Independents                 4036
# Indian National Congress     3475
# Bharatiya Janata Party       1896
#                             ...
# Rashtriya Kisan Party           1
# VSP                             1
# AB                              1
# PMP                             1
# JHSP                            1
# Name: partyname, Length: 1162, dtype: int64

# %%
datalessthan700 = data[data < 700]
datalessthan700
# Out:
# Communist Party Of India (Marxist)    525
# Indian Natioanl Congress (I)          491
# Communist Party Of India              450
# SP                                    434
# AAAP                                  432
#                                      ...
# Rashtriya Kisan Party                   1
# VSP                                     1
# AB                                      1
# PMP                                     1
# JHSP                                    1
# Name: partyname, Length: 1151, dtype: int64

# %%
data = df['partyname'].value_counts(ascending=False)
data
datalessthan700 = data[data < 700]
datalessthan700

def partname(value):
    if value in datalessthan700:
        return 'others'
    else:
        return value

df['partyname'] = df['partyname'].apply(partname)
df['partyname'].value_counts()
# Out:
# Independent                 27617
# others                      16343
# IND                          5619
# Independents                 4036
# Indian National Congress     3475
# Bharatiya Janata Party       1896
# Bahujan Samaj Party          1170
# Janata Dal                    943
# BSP                           938
# INC                           881
# BJP                           792
# Janata Party                  709
# Name: partyname, dtype: int64

# %%
df.replace(to_replace=['Independents'], value ='Independent', inplace=True)
df.replace(to_replace=['IND'], value ='Independent', inplace=True)
df['partyname'].replace(to_replace=['BJP'], value ='Bharatiya Janata Party', inplace=True)
df['partyname'].replace(to_replace=['BSP'], value ='Bahujan Samaj Party', inplace=True)
df['partyname'].replace(to_replace=['INC'], value ='Indian National Congress', inplace=True)

# %%
df['partyname'].value_counts()
# Out:
# Independent                 37272
# others                      16343
# Indian National Congress     4356
# Bharatiya Janata Party       2688
# Bahujan Samaj Party          2108
# Janata Dal                    943
# Janata Party                  709
# Name: partyname, dtype: int64

# %%
dataparty = df['partyabbre'].value_counts()

# %%
partyabbre700 = dataparty[dataparty < 700]

# %%
def partyabbre(value):
    if value in partyabbre700:
        return 'others'
    else:
        return value

df['partyabbre'] = df['partyabbre'].apply(partyabbre)
df['partyabbre'].value_counts()
# Out:
# Independent    37272
# others         15229
# INC             4356
# BJP             2915
# BSP             2124
# JD               943
# SP               864
# DDP              716
# Name: partyabbre, dtype: int64

# %%
df
# Out:
#                          st_name  year  pc_no                    pc_name  \
# 0      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 1      Andaman & Nicobar Islands  1977      1  Andaman & Nicobar Islands
# 2      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 3      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# 4      Andaman & Nicobar Islands  1980      1  Andaman & Nicobar Islands
# ...                          ...   ...    ...                        ...
# 73075                West Bengal  2014     42                    Birbhum
# 73077                West Bengal  2014     42                    Birbhum
# 73078                West Bengal  2014     42                    Birbhum
# 73079                West Bengal  2014     42                    Birbhum
# 73080                West Bengal  2014     42                    Birbhum
#
#       pc_type                 cand_name cand_sex                 partyname  \
# ...

# %%
df.describe()
# Out:
#                year         pc_no     totvotpoll      electors
# count  64419.000000  64419.000000   64419.000000  6.441900e+04
# mean    1995.115991     22.699033   49951.170990  1.090820e+06
# std        9.964904     19.262703  104648.290859  3.559855e+05
# min     1977.000000      1.000000       0.000000  1.947100e+04
# 25%     1989.000000      7.000000     793.000000  8.805930e+05
# 50%     1996.000000     18.000000    2513.000000  1.065484e+06
# 75%     1999.000000     33.000000   19970.000000  1.260158e+06
# max     2014.000000     85.000000  863358.000000  3.368399e+06

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
up_data_2014 = df[(df['year'] == 2014) & (df['st_name'] == 'Uttar Pradesh')]

# %%
up_data_2014_arrenge = up_data_2014.groupby('partyabbre')['totvotpoll'].sum()

# %%
up_data_2014_arrenge_max = pd.DataFrame(up_data_2014_arrenge.sort_values(ascending=False)).reset_index()
#df[(df['year'] == 2014) & (df['st_name'] == 'Uttar Pradesh') & (df['pc_name'] == 'Saharanpur')]

# %%
up_data_2014_arrenge_max
# Out:
#     partyabbre  totvotpoll
# 0          BJP    34318854
# 1           SP    17988967
# 2          BSP    15914194
# 3          INC     6061267
# 4       others     4802638
# 5  Independent     1414869

# %%
plt.figure(figsize = (12,5))
plt.bar(up_data_2014_arrenge_max['partyabbre'],up_data_2014_arrenge_max['totvotpoll'])
# Out:
# <BarContainer object of 6 artists>

# %%
Maharashtra_data_2014 = df[(df['year'] == 2014) & (df['st_name'] == 'Maharashtra')]
Maharashtra_data_2014_arrenge = Maharashtra_data_2014.groupby('partyabbre')['totvotpoll'].sum()
Maharashtra_data_2014_arrenge_max = pd.DataFrame(Maharashtra_data_2014_arrenge.sort_values(ascending=False)).reset_index()
Maharashtra_data_2014_arrenge_max
# Out:
#     partyabbre  totvotpoll
# 0       others    23222571
# 1          BJP    13308961
# 2          INC     8830190
# 3  Independent     1577114
# 4          BSP     1271680
# 5           SP       73732

# %%
plt.figure(figsize = (12,5))
plt.bar(Maharashtra_data_2014_arrenge_max['partyabbre'],Maharashtra_data_2014_arrenge_max['totvotpoll'])
# Out:
# <BarContainer object of 6 artists>

# %%
sns.countplot(data = df, x = 'cand_sex')
# Out:
# <Axes: xlabel='cand_sex', ylabel='count'>

# %%
sns.jointplot(x = df['totvotpoll'], y=df['electors'])

# %%
sns.histplot(x=df['electors'])
print("There is skewness in right side for electors",df['electors'].skew())
print("There is skewness in right side total votes",df['totvotpoll'].skew())
# Out:
# There is skewness in right side for electors 0.8846587056114168
# There is skewness in right side total votes 2.526205451518087

# %%
sns.boxplot(y = 'totvotpoll', hue='partyabbre', data =df)
# Out:
# <Axes: ylabel='totvotpoll'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_26516\4277794465.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
dummy = np.log(df['totvotpoll'] + 1)
dummy1 =(df['electors'])

# %%
dummy.skew()
# Out:
# 0.5016945913717573

# %%
sns.histplot(dummy)
# Out:
# <Axes: xlabel='totvotpoll', ylabel='Count'>
